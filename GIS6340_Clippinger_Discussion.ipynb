# %%
import arcpy

# %%
# raster file that I want to view
fin = r'C:\Users\clipp\Documents\GIS_6340\Week_05\data\m_4107246_ne_18_1_20120721.TIF'

# creates a Raster object
my_raster = arcpy.Raster(fin)

# calculates raster area
my_area = (my_raster.width * my_raster.height) * my_raster.meanCellWidth
print(my_area)
# Out:
# 46599840.0

# %%
# view raster. can now be used with Map Algebra and Spatial Analyst
my_raster
# Out:
# C:\Users\clipp\Documents\GIS_6340\Week_05\data\m_4107246_ne_18_1_20120721.TIF

# %%
# calculates NDWI index using Image Analysis function
NDWI_raster = arcpy.ia.NDWI(my_raster,4,2)

NDWI_raster
# Out:
# C:\Users\clipp\AppData\Local\Temp\xbe9d1cc0_af38_4804_88eb_cd4e27936691y0.afr
